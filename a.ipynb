# %%
import pandas as pd
df = pd.read_csv('seeder/metadata.csv', sep='\t')

df
# Out:
#           ID       FILE            AUTHOR  \
# 0          1      1.jpg  AACHEN, Hans von
# 1          2      2.jpg  AACHEN, Hans von
# 2          3      3.jpg  AACHEN, Hans von
# 3          4      4.jpg  AACHEN, Hans von
# 4          5      5.jpg  AACHEN, Hans von
# ...      ...        ...               ...
# 43450  43451  43451.jpg      ZÜRN, Martin
# 43451  43452  43452.jpg      ZÜRN, Martin
# 43452  43453  43453.jpg      ZÜRN, Martin
# 43453  43454  43454.jpg      ZÜRN, Martin
# 43454  43455        NaN     ZÜRN, Michael
#
#                                                BORN-DIED  \
# 0                        (b. 1552, Köln, d. 1615, Praha)
# 1                        (b. 1552, Köln, d. 1615, Praha)
# 2                        (b. 1552, Köln, d. 1615, Praha)
# 3                        (b. 1552, Köln, d. 1615, Praha)
# 4                        (b. 1552, Köln, d. 1615, Praha)
# ...                                                  ...
# ...

# %%
for _, row in df.head().iterrows():
    print(' '.join(row.drop(['ID', 'FILE', 'URL'])))
# Out:
# AACHEN, Hans von(b. 1552, Köln, d. 1615, Praha)Allegory1598Oil on copper, 56 x 47 cmAlte Pinakothek, MunichpaintingmythologicalGerman1601-1650
# AACHEN, Hans von(b. 1552, Köln, d. 1615, Praha)Bacchus, Ceres and Cupid-Oil on canvas, 163 x 113 cmKunsthistorisches Museum, ViennapaintingmythologicalGerman1601-1650
# AACHEN, Hans von(b. 1552, Köln, d. 1615, Praha)Joking Couple-Copperplate, 25 x 20 cmKunsthistorisches Museum, ViennapaintinggenreGerman1601-1650
# AACHEN, Hans von(b. 1552, Köln, d. 1615, Praha)Portrait of Emperor Rudolf II1590sOil on canvas, 60 x 48 cmKunsthistorisches Museum, ViennapaintingportraitGerman1601-1650
# AACHEN, Hans von(b. 1552, Köln, d. 1615, Praha)Self-Portrait with a Glass of Winec. 1596Oil on canvas, 53 x 44 cmPrivate collectionpaintingportraitGerman1601-1650
